# %%
[
    {"question": "什么是重力？", "answer": "重力是任何两个具有质量的物体之间存在的吸引力。"},
    {"question": "谁发现了相对论？", "answer": "阿尔伯特·爱因斯坦发现了相对论。"},
    {"question": "地球绕太阳转一圈需要多长时间？", "answer": "地球绕太阳转一圈大约需要365.25天。"}
]
# Out:
# [{'question': '什么是重力？', 'answer': '重力是任何两个具有质量的物体之间存在的吸引力。'},
#  {'question': '谁发现了相对论？', 'answer': '阿尔伯特·爱因斯坦发现了相对论。'},
#  {'question': '地球绕太阳转一圈需要多长时间？', 'answer': '地球绕太阳转一圈大约需要365.25天。'}]

# %%
pip install langchain
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.  Downloading langchain-0.2.17-py3-none-any.whl (1.0 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.20.3 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
# ...

# %%
pip install --upgrade --force-reinstall langchain
# Out:
# ...
#   Using cached langchain-0.2.17-py3-none-any.whl (1.0 MB)
# ...
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# ...
#   Using cached langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# ...
#   Using cached pydantic-2.10.1-py3-none-any.whl (455 kB)
# ...
#   Using cached langsmith-0.1.146-py3-none-any.whl (311 kB)
# ...
#   Using cached langchain_core-0.2.43-py3-none-any.whl (397 kB)
# ...
#   Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# ...
#   Using cached aiohttp-3.10.11-cp38-cp38-win_amd64.whl (384 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# ...
#   Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# ...
#   Using cached multidict-6.1.0-cp38-cp38-win_amd64.whl (28 kB)
# ...
#   Using cached yarl-1.15.2-cp38-cp38-win_amd64.whl (84 kB)
# ...
#   Using cached frozenlist-1.5.0-cp38-cp38-win_amd64.whl (51 kB)
# ...
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# ...

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 0.2.17
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author: None
# Author-email: None
# License: MIT
# Location: d:\anaconda\lib\site-packages
# Requires: aiohttp, async-timeout, tenacity, numpy, requests, langchain-core, langchain-text-splitters, SQLAlchemy, PyYAML, langsmith, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# 导入必要的库
import json
from langchain.chains import Chain
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI

# 加载本地知识库
with open('knowledge_base.json', 'r') as f:
    knowledge_base = json.load(f)

# 定义一个函数来根据问题检索答案
def retrieve_answer(question):
    for qa in knowledge_base:
        if qa['question'].lower() == question.lower():
            return qa['answer']
    return None

prompt_template = PromptTemplate(
    input_variables=["question"],
    template="问题：{question}\n请给出答案："  # 这是一个假设性的模板，实际不用于检索
)


# 示例使用
questions = [
    "什么是重力？",
    "谁发现了相对论？",
    "地球绕太阳转一圈需要多长时间？",
    "光的速度是多少？"  # 这个问题在知识库中不存在，用于测试未找到答案的情况
]

for question in questions:
    answer = retrieve_answer(question)
    print(f"问题: {question}\n答案: {answer if answer else '未找到答案'}\n")
